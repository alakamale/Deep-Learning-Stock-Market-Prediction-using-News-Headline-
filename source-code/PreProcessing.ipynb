# %% [markdown]
# # Pre Processing
# 1. Convert coloumn object to Datetime
# 2. Truncate the data for concurrecy in date across stocks
# 3. Date order are in same order for all stocks

# %%
import pandas as pd
from datetime import datetime

# %%
DJIA = pd.read_csv("Stocks/DJIA_table.csv")
MMM = pd.read_csv("Stocks/MMM.csv")
AMEX = pd.read_csv("Stocks/AXP.csv")
APPLE = pd.read_csv("Stocks/AAPL.csv")
BOEING = pd.read_csv("Stocks/BA.csv")

# %% [markdown]
# # Step 1

# %%
# Data Types
MMM.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
print("Shape of dataframes \n 1. DJIA : {} \n 2. MMM : {} \n 3. AMEX : {} \n 4. APPLE : {} \n 5. BOEING : {} \n"
      .format(DJIA.shape, MMM.shape, AMEX.shape, APPLE.shape, BOEING.shape, ))
# Out:
# Shape of dataframes
#  1. DJIA : (1989, 7)
#  2. MMM : (2537, 7)
#  3. AMEX : (2537, 7)
#  4. APPLE : (2537, 7)
#  5. BOEING : (2537, 7)

# %% [markdown]
# ##### Creating consolidated dataset for all stocks
# 1. Truncate the data for MMM, AMEX, APPLE, BOEING to match up with DJIA
# 2. Reversing rows for MMM, AMEX, APPLE, BOEING to match up with DJIA

# %%
# Truncating
MMM = MMM.truncate(before=548)                  #  Truncating data from *-*-2006 to 07-08-2008
AMEX = AMEX.truncate(before=548)                #  Truncating data from *-*-2006 to 07-08-2008
APPLE = APPLE.truncate(before=548)              #  Truncating data from *-*-2006 to 07-08-2008
BOEING = BOEING.truncate(before=548)            #  Truncating data from *-*-2006 to 07-08-2008

# %%
# Saving data to csv
DJIA.to_csv("processed_data/DJIA.csv", index= False)
MMM.iloc[::-1].to_csv("processed_data/MMM.csv", index= False)
AMEX.iloc[::-1].to_csv("processed_data/AXP.csv", index= False)
APPLE.iloc[::-1].to_csv("processed_data/AAPL.csv", index= False)
BOEING.iloc[::-1].to_csv("processed_data/BA.csv", index= False)

# %%
print("Shape of dataframes \n 1. DJIA : {} \n 2. MMM : {} \n 3. AMEX : {} \n 4. APPLE : {} \n 5. BOEING : {} \n"
      .format(DJIA.shape, MMM.shape, AMEX.shape, APPLE.shape, BOEING.shape, ))
# Out:
# Shape of dataframes
#  1. DJIA : (1989, 7)
#  2. MMM : (1989, 7)
#  3. AMEX : (1989, 7)
#  4. APPLE : (1989, 7)
#  5. BOEING : (1989, 7)

# %%
# Copy RedditNews CSV
from shutil import copyfile
copyfile("News/RedditNews.csv", "processed_data/RedditNews.csv")
# Out:
# 'processed_data/RedditNews.csv'

# %% [markdown]
# # Step 2

# %%
DJIA = pd.read_csv("processed_data/DJIA.csv")
MMM = pd.read_csv("processed_data/MMM.csv")
AMEX = pd.read_csv("processed_data/AXP.csv")
APPLE = pd.read_csv("processed_data/AAPL.csv")
BOEING = pd.read_csv("processed_data/BA.csv")
NEWS = pd.read_csv("processed_data/RedditNews.csv")

# %% [markdown]
# ##### Converting date object into datetime

# %%
DJIA['Date'] = pd.to_datetime(DJIA['Date'])
MMM['Date'] = pd.to_datetime(MMM['Date'])
AMEX['Date'] = pd.to_datetime(AMEX['Date'])
APPLE['Date'] = pd.to_datetime(APPLE['Date'])
BOEING['Date'] = pd.to_datetime(BOEING['Date'])
NEWS['Date'] = pd.to_datetime(NEWS['Date'])

# %% [markdown]
# # Basic Natural Language Procesing

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('Combined_News_DJIA.csv')

# %%
data.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3  2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4  2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# ...

# %%
train = data[data['Date'] < '2015-01-01']
test = data[data['Date'] > '2014-12-31']

# %% [markdown]
# ## Text Processing

# %%
example = train.iloc[3,10]
print(example)
# Out:
# b"The commander of a Navy air reconnaissance squadron that provides the President and the defense secretary the airborne ability to command the nation's nuclear weapons has been relieved of duty"

# %%
example2 = example.lower()
print(example2)
# Out:
# b"the commander of a navy air reconnaissance squadron that provides the president and the defense secretary the airborne ability to command the nation's nuclear weapons has been relieved of duty"

# %%
example3 = CountVectorizer().build_tokenizer()(example2)
print(example3)
# Out:
# ['the', 'commander', 'of', 'navy', 'air', 'reconnaissance', 'squadron', 'that', 'provides', 'the', 'president', 'and', 'the', 'defense', 'secretary', 'the', 'airborne', 'ability', 'to', 'command', 'the', 'nation', 'nuclear', 'weapons', 'has', 'been', 'relieved', 'of', 'duty']

# %%
pd.DataFrame([[x,example3.count(x)] for x in set(example3)], columns = ['Word', 'Count'])
# Out:
#               Word  Count
# 0        president      1
# 1             that      1
# 2        secretary      1
# 3          ability      1
# 4             duty      1
# 5              the      5
# 6             been      1
# 7             navy      1
# 8         airborne      1
# 9         squadron      1
# 10         nuclear      1
# 11              to      1
# 12  reconnaissance      1
# 13         command      1
# 14             and      1
# 15         weapons      1
# 16          nation      1
# 17        relieved      1
# 18         defense      1
# 19             has      1
# 20        provides      1
# 21              of      2
# 22             air      1
# 23       commander      1

# %% [markdown]
# ## Basic Model Training and Testing

# %%
trainheadlines = []
for row in range(0,len(train.index)):
    trainheadlines.append(' '.join(str(x) for x in train.iloc[row,2:27]))

# %%
basicvectorizer = CountVectorizer()
basictrain = basicvectorizer.fit_transform(trainheadlines)
print(basictrain.shape)
# Out:
# (1611, 31675)

# %%
#  train a logistic regression model using this data.
basicmodel = LogisticRegression()
basicmodel = basicmodel.fit(basictrain, train["Label"])

# %%
testheadlines = []
for row in range(0,len(test.index)):
    testheadlines.append(' '.join(str(x) for x in test.iloc[row,2:27]))
basictest = basicvectorizer.transform(testheadlines)
predictions = basicmodel.predict(basictest)

# %%
pd.crosstab(test["Label"], predictions, rownames=["Actual"], colnames=["Predicted"])
# Out:
# Predicted   0    1
# Actual
# 0          61  125
# 1          92  100

# %%
basicwords = basicvectorizer.get_feature_names()
basiccoeffs = basicmodel.coef_.tolist()[0]
coeffdf = pd.DataFrame({'Word' : basicwords, 
                        'Coefficient' : basiccoeffs})
coeffdf = coeffdf.sort_values(['Coefficient', 'Word'], ascending=[0, 1])
coeffdf.head(10)
# Out:
#             Word  Coefficient
# 19419    nigeria     0.497924
# 25261       self     0.452526
# 29286         tv     0.428011
# 15998      korea     0.425863
# 20135   olympics     0.425716
# 15843      kills     0.411636
# 26323         so     0.411267
# 29256       turn     0.394855
# 10874      fears     0.388555
# 28274  territory     0.384031

# %%
coeffdf.tail(10)
# Out:
#             Word  Coefficient
# 27299   students    -0.424441
# 8478         did    -0.427079
# 6683       congo    -0.431925
# 12818    hacking    -0.444069
# 7139     country    -0.448570
# 16949        low    -0.463116
# 3651       begin    -0.470454
# 25433        sex    -0.494555
# 24754  sanctions    -0.549725
# 24542        run    -0.587794

# %% [markdown]
# ## Advance Model
# n-gram

# %%
advancedvectorizer = CountVectorizer(ngram_range=(2,2))
advancedtrain = advancedvectorizer.fit_transform(trainheadlines)

# %%
print(advancedtrain.shape)
# Out:
# (1611, 366721)

# %%
advancedmodel = LogisticRegression()
advancedmodel = advancedmodel.fit(advancedtrain, train["Label"])

# %%
testheadlines = []
for row in range(0,len(test.index)):
    testheadlines.append(' '.join(str(x) for x in test.iloc[row,2:27]))
advancedtest = advancedvectorizer.transform(testheadlines)
advpredictions = advancedmodel.predict(advancedtest)

# %%
pd.crosstab(test["Label"], advpredictions, rownames=["Actual"], colnames=["Predicted"])
# Out:
# Predicted   0    1
# Actual
# 0          66  120
# 1          45  147

# %%
advwords = advancedvectorizer.get_feature_names()
advcoeffs = advancedmodel.coef_.tolist()[0]
advcoeffdf = pd.DataFrame({'Words' : advwords, 
                        'Coefficient' : advcoeffs})
advcoeffdf = advcoeffdf.sort_values(['Coefficient', 'Words'], ascending=[0, 1])
advcoeffdf.head(10)
# Out:
#             Words  Coefficient
# 272047   right to     0.286533
# 24710   and other     0.275274
# 285392     set to     0.274698
# 316194  the first     0.262873
# 157511   in china     0.227943
# 159522   in south     0.224184
# 125870   found in     0.219130
# 124411  forced to     0.216726
# 173246     it has     0.211137
# 322590    this is     0.209239

# %%
advcoeffdf.tail(10)
# Out:
#               Words  Coefficient
# 326846      to help    -0.198495
# 118707      fire on    -0.201654
# 155038        if he    -0.209702
# 242528   people are    -0.211303
# 31669    around the    -0.213362
# 321333     there is    -0.215699
# 327113      to kill    -0.221812
# 340714        up in    -0.226289
# 358917    with iran    -0.227516
# 315485  the country    -0.331153
